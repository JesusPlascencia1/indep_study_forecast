# %%
# !python test_installation.py
# Out:
# Traceback (most recent call last):
#   File "/Users/jesusplascencia/Modern-Time-Series-Forecasting-with-Python/test_installation.py", line 8, in <module>
#     f"GPU: {torch.cuda.is_available()} | # of GPU: {torch.cuda.device_count()}| Default GPU Name: {torch.cuda.get_device_name(0)}"
#                                                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py", line 584, in get_device_name
#     return get_device_properties(device).name
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py", line 616, in get_device_properties
#     _lazy_init()  # will define _get_device_properties
#     ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py", line 403, in _lazy_init
#     raise AssertionError("Torch not compiled with CUDA enabled")
# ...
